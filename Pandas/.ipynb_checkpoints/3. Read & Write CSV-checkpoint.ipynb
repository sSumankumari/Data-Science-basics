# %% [markdown]
# # Read and Write Excel and CSV file

# %%
import pandas as pd
df = pd.read_csv("stock_data.csv")
df
# Out:
#   stock data     Unnamed: 1 Unnamed: 2 Unnamed: 3     Unnamed: 4
# 0    tickers            eps    revenue      price         people
# 1     GOOGLE          27.82         87        845     larry page
# 2        WMT           4.61        484         65           N.A.
# 3       MSFT             -1         85         64     bill gates
# 4        RIL  not available         50       1023  mukesh ambani
# 5       TATA            5.6         -1       N.A.     ratan tata

# %%
df = pd.read_csv("stock_data.csv", skiprows=1)
df
# Out:
#   tickers            eps  revenue price         people
# 0  GOOGLE          27.82       87   845     larry page
# 1     WMT           4.61      484    65           N.A.
# 2    MSFT             -1       85    64     bill gates
# 3     RIL  not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  N.A.     ratan tata

# %%
df = pd.read_csv("stock_data.csv", header=1)

# %%
df
# Out:
#   tickers            eps  revenue price         people
# 0  GOOGLE          27.82       87   845     larry page
# 1     WMT           4.61      484    65           N.A.
# 2    MSFT             -1       85    64     bill gates
# 3     RIL  not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  N.A.     ratan tata

# %%
df = pd.read_csv("stock_data.csv", header=None)
df
# Out:
#             0              1        2      3              4
# 0  stock data            NaN      NaN    NaN            NaN
# 1     tickers            eps  revenue  price         people
# 2      GOOGLE          27.82       87    845     larry page
# 3         WMT           4.61      484     65           N.A.
# 4        MSFT             -1       85     64     bill gates
# 5         RIL  not available       50   1023  mukesh ambani
# 6        TATA            5.6       -1   N.A.     ratan tata

# %%
df = pd.read_csv("stock_data.csv", header=None, names=['tickers', 'eps', 'revenue', 'price', 'people'])
df
# Out:
#       tickers            eps  revenue  price         people
# 0  stock data            NaN      NaN    NaN            NaN
# 1     tickers            eps  revenue  price         people
# 2      GOOGLE          27.82       87    845     larry page
# 3         WMT           4.61      484     65           N.A.
# 4        MSFT             -1       85     64     bill gates
# 5         RIL  not available       50   1023  mukesh ambani
# 6        TATA            5.6       -1   N.A.     ratan tata

# %%
df = pd.read_csv("stock_data.csv", header=1)
df
# Out:
#   tickers            eps  revenue price         people
# 0  GOOGLE          27.82       87   845     larry page
# 1     WMT           4.61      484    65           N.A.
# 2    MSFT             -1       85    64     bill gates
# 3     RIL  not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  N.A.     ratan tata

# %%
df = pd.read_csv("stock_data.csv", header=1, nrows=3)
df
# Out:
#   tickers    eps  revenue  price      people
# 0  GOOGLE  27.82       87    845  larry page
# 1     WMT   4.61      484     65        N.A.
# 2    MSFT  -1.00       85     64  bill gates

# %%
df = pd.read_csv("stock_data.csv", na_values=['not available', 'N.A.', -1])
df
# Out:
#   stock data Unnamed: 1 Unnamed: 2 Unnamed: 3     Unnamed: 4
# 0    tickers        eps    revenue      price         people
# 1     GOOGLE      27.82         87        845     larry page
# 2        WMT       4.61        484         65            NaN
# 3       MSFT        NaN         85         64     bill gates
# 4        RIL        NaN         50       1023  mukesh ambani
# 5       TATA        5.6        NaN        NaN     ratan tata

# %%
df = pd.read_csv("stock_data.csv", header=1,
                na_values={
                    'eps': ['not available', 'N.A.'],
                    'revenue': ['not available', 'N.A.', -1],
                    'people': ['not available','N.A.']
                })
df
# Out:
#   tickers    eps  revenue price         people
# 0  GOOGLE  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65            NaN
# 2    MSFT  -1.00     85.0    64     bill gates
# 3     RIL    NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  N.A.     ratan tata

# %%
# Writing to CSV
df.to_csv('New_stock_data.csv', index=False)

# %%
df.to_csv('new_stock.xlsx')

# %%
df
# Out:
#   tickers    eps  revenue price         people
# 0  GOOGLE  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65            NaN
# 2    MSFT  -1.00     85.0    64     bill gates
# 3     RIL    NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  N.A.     ratan tata

# %%
df.columns
# Out:
# Index(['tickers', 'eps', 'revenue', 'price', 'people'], dtype='object')

# %%
df.to_csv('new.csv', columns=['eps', 'people'])

# %% [markdown]
# ## Reading and writing Excel

# %%
# df1 = pd.read_excel("new_stock.xlsx", "Sheet1")
# df1

# %%
def convert_people_cell(cell):
    if cell=='N.A.':
        return 'sam walton'
    return cell
def convert_people_cell(cell):
    if cell=='not available':
        return None
    return cell
# df1 = pd.read_excel("new_stock.xlsx", "Sheet1",
#                     converters = {
#                         'people': convert_people_cell,
#                         'eps': convert_eps_cell
#                 })
# df1

# %%
# Writing to the excel file
df.to_excel("new_stock.xlsx", sheet_name='stocks')

# %%
df
# Out:
#   tickers    eps  revenue price         people
# 0  GOOGLE  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65            NaN
# 2    MSFT  -1.00     85.0    64     bill gates
# 3     RIL    NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  N.A.     ratan tata

# %%
# df.to_excel("new_stock.xlsx", sheet_name='stocks', startcol=3)
# df.to_excel("new_stock.xlsx", sheet_name='stocks', startcol=3, index=False)
# df
