# %% [markdown]
# # Dataframe using Pandas

# %%
import pandas as pd
df = pd.read_csv("weather_data.csv")

# %%
df
# Out:
#           Day  Temperature  Windspeed  Event
# 0  01-01-2022           32          6   Rain
# 1  01-02-2022           35          7  Sunny
# 2  01-03-2022           28          2   Snow
# 3  01-04-2022           24          3   Snow
# 4  01-05-2022           32          5   Rain
# 5  01-06-2022           32          7  Sunny
# 6  01-07-2022           37          4   Rain

# %%
# By using Python dictionary
weather_data = {
    'day': ['01-01-2022', '01-02-2022', '01-03-2022', '01-04-2022', '01-05-2022', '01-06-2022', '01-07-2022'],
    'temperature': [32, 35, 28, 24, 32, 32, 37],
    'windspeed': [6, 7, 2, 3, 5, 7, 4],
    'event': ['rain', 'sunny', 'snow', 'snow', 'rain', 'sunny', 'rain']
}
df1 = pd.DataFrame(weather_data)
df1
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2022           32          6   rain
# 1  01-02-2022           35          7  sunny
# 2  01-03-2022           28          2   snow
# 3  01-04-2022           24          3   snow
# 4  01-05-2022           32          5   rain
# 5  01-06-2022           32          7  sunny
# 6  01-07-2022           37          4   rain

# %%
df.shape
# Out:
# (7, 4)

# %%
rows, columns = df.shape

# %%
rows
# columns
# Out:
# 7

# %%
# df.head()
df.head(3)
# Out:
#           Day  Temperature  Windspeed  Event
# 0  01-01-2022           32          6   Rain
# 1  01-02-2022           35          7  Sunny
# 2  01-03-2022           28          2   Snow

# %%
# df.tail()
df.tail(3)
# Out:
#           Day  Temperature  Windspeed  Event
# 4  01-05-2022           32          5   Rain
# 5  01-06-2022           32          7  Sunny
# 6  01-07-2022           37          4   Rain

# %%
# To print row no. 2 to 4
df[2:5]
# Out:
#           Day  Temperature  Windspeed Event
# 2  01-03-2022           28          2  Snow
# 3  01-04-2022           24          3  Snow
# 4  01-05-2022           32          5  Rain

# %%
df[3:]
# Out:
#           Day  Temperature  Windspeed  Event
# 3  01-04-2022           24          3   Snow
# 4  01-05-2022           32          5   Rain
# 5  01-06-2022           32          7  Sunny
# 6  01-07-2022           37          4   Rain

# %%
df.columns
# Out:
# Index(['Day', 'Temperature', 'Windspeed', 'Event'], dtype='object')

# %%
df['Event']
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# 6     Rain
# Name: Event, dtype: object

# %%
type(df['Windspeed'])
# Out:
# pandas.core.series.Series

# %%
df1[:]
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2022           32          6   rain
# 1  01-02-2022           35          7  sunny
# 2  01-03-2022           28          2   snow
# 3  01-04-2022           24          3   snow
# 4  01-05-2022           32          5   rain
# 5  01-06-2022           32          7  sunny
# 6  01-07-2022           37          4   rain

# %%
df1[['event', 'day', 'event']]
# Out:
#    event         day  event
# 0   rain  01-01-2022   rain
# 1  sunny  01-02-2022  sunny
# 2   snow  01-03-2022   snow
# 3   snow  01-04-2022   snow
# 4   rain  01-05-2022   rain
# 5  sunny  01-06-2022  sunny
# 6   rain  01-07-2022   rain

# %%
# df1['temperature'].max()
# df1['temperature'].min()
df1['temperature'].mean()
# Out:
# 31.428571428571427

# %%
# Statistic of the data
df.describe()
# Out:
#        Temperature  Windspeed
# count     7.000000   7.000000
# mean     31.428571   4.857143
# std       4.314979   1.951800
# min      24.000000   2.000000
# 25%      30.000000   3.500000
# 50%      32.000000   5.000000
# 75%      33.500000   6.500000
# max      37.000000   7.000000

# %%
# df1[df1.temperature>32]
df1[df1.temperature==df1.temperature.max()]
# df1[df1.temperature==df1.temperature.mean()]
# Out:
#           day  temperature  windspeed event
# 6  01-07-2022           37          4  rain

# %%
df1[['day', 'event']][df1.temperature==df1.temperature.max()]
# Out:
#           day event
# 6  01-07-2022  rain

# %%
# Setting the index of the dataframe
# df.index
df1.set_index('day') # dataframe not modified
# Out:
#             temperature  windspeed  event
# day
# 01-01-2022           32          6   rain
# 01-02-2022           35          7  sunny
# 01-03-2022           28          2   snow
# 01-04-2022           24          3   snow
# 01-05-2022           32          5   rain
# 01-06-2022           32          7  sunny
# 01-07-2022           37          4   rain

# %%
df1
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2022           32          6   rain
# 1  01-02-2022           35          7  sunny
# 2  01-03-2022           28          2   snow
# 3  01-04-2022           24          3   snow
# 4  01-05-2022           32          5   rain
# 5  01-06-2022           32          7  sunny
# 6  01-07-2022           37          4   rain

# %%
# To modifiy the dataframe
df1.set_index('day', inplace = True)

# %%
df1
# Out:
#             temperature  windspeed  event
# day
# 01-01-2022           32          6   rain
# 01-02-2022           35          7  sunny
# 01-03-2022           28          2   snow
# 01-04-2022           24          3   snow
# 01-05-2022           32          5   rain
# 01-06-2022           32          7  sunny
# 01-07-2022           37          4   rain

# %%
df1.loc['01-03-2022']
# Out:
# temperature      28
# windspeed         2
# event          snow
# Name: 01-03-2022, dtype: object

# %%
# To Reset the index
df1.reset_index(inplace=True)

# %%
df1
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2022           32          6   rain
# 1  01-02-2022           35          7  sunny
# 2  01-03-2022           28          2   snow
# 3  01-04-2022           24          3   snow
# 4  01-05-2022           32          5   rain
# 5  01-06-2022           32          7  sunny
# 6  01-07-2022           37          4   rain

# %%
df1.set_index('event', inplace=True)

# %%
df1
# Out:
#               day  temperature  windspeed
# event
# rain   01-01-2022           32          6
# sunny  01-02-2022           35          7
# snow   01-03-2022           28          2
# snow   01-04-2022           24          3
# rain   01-05-2022           32          5
# sunny  01-06-2022           32          7
# rain   01-07-2022           37          4

# %%
df1.loc['snow']
# Out:
#               day  temperature  windspeed
# event
# snow   01-03-2022           28          2
# snow   01-04-2022           24          3
