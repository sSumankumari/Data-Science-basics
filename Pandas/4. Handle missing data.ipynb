# %% [markdown]
# # Handle Missing data using Pandas

# %%
import pandas as pd
df = pd.read_csv("weather_data2.csv")
df
# Out:
#           day  temperature  windspeed   event
# 0  01-01-2022         32.0        6.0    rain
# 1  01-02-2022          NaN        8.0   sunny
# 2  01-03-2022         28.0        5.0     NaN
# 3  01-04-2022          NaN        NaN    rain
# 4  01-05-2022         32.0        7.0    snow
# 5  01-06-2022          NaN        NaN   sunny
# 6  01-07-2022          NaN        9.0     NaN
# 7  01-08-2022         35.0        6.0   sunny
# 8  01-09-2022         40.0        NaN    snow
# 9  01-10-2022         37.0        8.0  cloudy

# %%
type(df.day)
# Out:
# pandas.core.series.Series

# %%
type(df.day[3])
# Out:
# str

# %%
df = pd.read_csv("weather_data2.csv", parse_dates=['day'])
df
# Out:
#          day  temperature  windspeed   event
# 0 2022-01-01         32.0        6.0    rain
# 1 2022-01-02          NaN        8.0   sunny
# 2 2022-01-03         28.0        5.0     NaN
# 3 2022-01-04          NaN        NaN    rain
# 4 2022-01-05         32.0        7.0    snow
# 5 2022-01-06          NaN        NaN   sunny
# 6 2022-01-07          NaN        9.0     NaN
# 7 2022-01-08         35.0        6.0   sunny
# 8 2022-01-09         40.0        NaN    snow
# 9 2022-01-10         37.0        8.0  cloudy

# %%
type(df.day[3])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.set_index('day', inplace=True)
df
# Out:
#             temperature  windspeed   event
# day
# 2022-01-01         32.0        6.0    rain
# 2022-01-02          NaN        8.0   sunny
# 2022-01-03         28.0        5.0     NaN
# 2022-01-04          NaN        NaN    rain
# 2022-01-05         32.0        7.0    snow
# 2022-01-06          NaN        NaN   sunny
# 2022-01-07          NaN        9.0     NaN
# 2022-01-08         35.0        6.0   sunny
# 2022-01-09         40.0        NaN    snow
# 2022-01-10         37.0        8.0  cloudy

# %%
# To replace na values
new_df = df.fillna('-')
new_df
# Out:
#            temperature windspeed   event
# day
# 2022-01-01        32.0       6.0    rain
# 2022-01-02           -       8.0   sunny
# 2022-01-03        28.0       5.0       -
# 2022-01-04           -         -    rain
# 2022-01-05        32.0       7.0    snow
# 2022-01-06           -         -   sunny
# 2022-01-07           -       9.0       -
# 2022-01-08        35.0       6.0   sunny
# 2022-01-09        40.0         -    snow
# 2022-01-10        37.0       8.0  cloudy

# %%
# different values for different columns
new_df = df.fillna({
    'temperature':0,
    'windspeed':'-',
    'event':'no event'
})
new_df
# Out:
#             temperature windspeed     event
# day
# 2022-01-01         32.0       6.0      rain
# 2022-01-02          0.0       8.0     sunny
# 2022-01-03         28.0       5.0  no event
# 2022-01-04          0.0         -      rain
# 2022-01-05         32.0       7.0      snow
# 2022-01-06          0.0         -     sunny
# 2022-01-07          0.0       9.0  no event
# 2022-01-08         35.0       6.0     sunny
# 2022-01-09         40.0         -      snow
# 2022-01-10         37.0       8.0    cloudy

# %%
# to carry forward previous values for the na_values
# ffill--> forward fill & bfill--> backward fill
# new_df = df.fillna(method='ffill')
new_df = df.fillna(method='bfill')
# new_df = df.fillna(method='bfill', axis='columns')
new_df = df.fillna(method='bfill', limit=1)

new_df
# Out:
#             temperature  windspeed   event
# day
# 2022-01-01         32.0        6.0    rain
# 2022-01-02         28.0        8.0   sunny
# 2022-01-03         28.0        5.0    rain
# 2022-01-04         32.0        7.0    rain
# 2022-01-05         32.0        7.0    snow
# 2022-01-06          NaN        9.0   sunny
# 2022-01-07         35.0        9.0   sunny
# 2022-01-08         35.0        6.0   sunny
# 2022-01-09         40.0        8.0    snow
# 2022-01-10         37.0        8.0  cloudy

# %%
# new_df = df.interpolate()
new_df = df.interpolate(method='time')
new_df
# Out:
#             temperature  windspeed   event
# day
# 2022-01-01         32.0        6.0    rain
# 2022-01-02         30.0        8.0   sunny
# 2022-01-03         28.0        5.0     NaN
# 2022-01-04         30.0        6.0    rain
# 2022-01-05         32.0        7.0    snow
# 2022-01-06         33.0        8.0   sunny
# 2022-01-07         34.0        9.0     NaN
# 2022-01-08         35.0        6.0   sunny
# 2022-01-09         40.0        7.0    snow
# 2022-01-10         37.0        8.0  cloudy

# %%
# to drop rows with na value
new_df1 = df.dropna()
new_df1
# Out:
#             temperature  windspeed   event
# day
# 2022-01-01         32.0        6.0    rain
# 2022-01-05         32.0        7.0    snow
# 2022-01-08         35.0        6.0   sunny
# 2022-01-10         37.0        8.0  cloudy

# %%
new_df1 = df.dropna(how='all')
new_df1
# Out:
#             temperature  windspeed   event
# day
# 2022-01-01         32.0        6.0    rain
# 2022-01-02          NaN        8.0   sunny
# 2022-01-03         28.0        5.0     NaN
# 2022-01-04          NaN        NaN    rain
# 2022-01-05         32.0        7.0    snow
# 2022-01-06          NaN        NaN   sunny
# 2022-01-07          NaN        9.0     NaN
# 2022-01-08         35.0        6.0   sunny
# 2022-01-09         40.0        NaN    snow
# 2022-01-10         37.0        8.0  cloudy

# %%
new_df1 = df.dropna(thresh=1)
new_df1
# Out:
#             temperature  windspeed   event
# day
# 2022-01-01         32.0        6.0    rain
# 2022-01-02          NaN        8.0   sunny
# 2022-01-03         28.0        5.0     NaN
# 2022-01-04          NaN        NaN    rain
# 2022-01-05         32.0        7.0    snow
# 2022-01-06          NaN        NaN   sunny
# 2022-01-07          NaN        9.0     NaN
# 2022-01-08         35.0        6.0   sunny
# 2022-01-09         40.0        NaN    snow
# 2022-01-10         37.0        8.0  cloudy

# %%
dt = pd.date_range("01-01-2022", "01-10-2022")
idx = pd.DatetimeIndex(dt)
df.reindex(idx)
# Out:
#             temperature  windspeed   event
# 2022-01-01         32.0        6.0    rain
# 2022-01-02          NaN        8.0   sunny
# 2022-01-03         28.0        5.0     NaN
# 2022-01-04          NaN        NaN    rain
# 2022-01-05         32.0        7.0    snow
# 2022-01-06          NaN        NaN   sunny
# 2022-01-07          NaN        9.0     NaN
# 2022-01-08         35.0        6.0   sunny
# 2022-01-09         40.0        NaN    snow
# 2022-01-10         37.0        8.0  cloudy
